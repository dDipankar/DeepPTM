# %%
from __future__ import print_function
from __future__ import division

from collections import OrderedDict
import os
import sys
import warnings

import argparse
import logging
import h5py as h5
import numpy as np
import pandas as pd
import scipy.io

import six
from six.moves import range
import csv
import math as ma
from sklearn.metrics import roc_auc_score, confusion_matrix, average_precision_score,roc_curve,auc,precision_recall_curve
from keras.preprocessing import sequence
from keras.optimizers import RMSprop,Adam, Adadelta, Nadam, Adamax, SGD, Adagrad
from keras.models import Sequential
from keras.layers.core import  Dropout, Activation, Flatten
from keras.regularizers import l1,l2,l1_l2
from keras.constraints import maxnorm
#from keras.layers.recurrent import LSTM, GRU
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import Conv1D, MaxPooling1D, Dense, LSTM, Bidirectional
from sklearn.ensemble import GradientBoostingClassifier
import matplotlib.pyplot as plt

# %%
def features_selected_gbc(X_tr, y_tr):
	regr= GradientBoostingClassifier(random_state=0)
	regr.fit(X_tr, y_tr)
	coef = regr.feature_importances_
	parameters = {"coef": coef,
				  "model":regr}
	return parameters

# %%
h5filename = "histonemodTF_resample_ncl.h5"
h5file = h5.File(h5filename,'r')
input_features = h5file['input/H3K4me3_RPKM']
output_H3K4me3 = h5file['output/H3K4me3']
print(input_features.shape)
print(output_H3K4me3.shape)
# Out:
# (26747, 43)
# (26747,)

# %%
 input_features = np.array(input_features)
 output_H3K4me3 = np.array(output_H3K4me3)
 output_H3K4me3_reshape = output_H3K4me3.reshape(len(output_H3K4me3),1)

# %%
#combine the label with input dna
input_features_label = np.concatenate((input_features,output_H3K4me3_reshape), axis=1)
H3K4me3_df = pd.DataFrame(output_H3K4me3)
pos_label= H3K4me3_df.loc[H3K4me3_df.iloc[:,0]==1]
pos_label_ix = np.array(pos_label.index)
neg_label = H3K4me3_df.loc[H3K4me3_df.iloc[:,0]==0]
neg_label_ix = np.array(neg_label.index)
pos_sam_H3K4me3 = input_features_label[pos_label_ix,:]
neg_sam_H3K4me3 = input_features_label[neg_label_ix,:]
np.random.shuffle(pos_sam_H3K4me3)
np.random.shuffle(pos_sam_H3K4me3)
print(pos_sam_H3K4me3.shape)
print(neg_sam_H3K4me3.shape)
# Out:
# (9721, 44)
# (17026, 44)

# %%
train_neg_sample = int(ma.ceil(neg_sam_H3K4me3.shape[0] *0.7))
train_pos_sample = int(ma.ceil(pos_sam_H3K4me3.shape[0] *0.7))
train_neg_H3K4me3 = neg_sam_H3K4me3[0:train_neg_sample,:]
train_pos_H3K4me3 = pos_sam_H3K4me3 [0:train_pos_sample,:]
train_neg_pos_H3K4me3 = np.concatenate((train_neg_H3K4me3, train_pos_H3K4me3),axis = 0)
np.random.shuffle(train_neg_pos_H3K4me3)
X_train_H3K4me3 = train_neg_pos_H3K4me3[:,0:30]
Y_train_H3K4me3 = train_neg_pos_H3K4me3[:,30]
Y_train_H3K4me3 = np.array(Y_train_H3K4me3, dtype='int64')
frq = np.bincount(Y_train_H3K4me3)
#print(frq)
print(X_train_H3K4me3.shape)
print(Y_train_H3K4me3.shape)
print(Y_train_H3K4me3[0:100])
# Out:
# (18724, 30)
# (18724,)
# [ 0  2  0  1  2  0  1  1  3  1  0  0  2  0  8  0  1  3  2  0  1  0  8  4  1
#   0  5  4  0  3  0  0  0  6  1  1  2  1  5  1  3  1  1  0  0  8  2  0  0  0
#   0  0  1  1  1  2  0  1  1  0  0  0  0 22  3  0  0  1  1  1  2  4  6  1 12
#   6  1  0  0  0  0  0  0  0  7  1 16  0  0  1  0  1  0  0  0 11  1  1  2  1]

# %%
# feature selection using gbc
param = features_selected_gbc(X_train_H3K4me3, Y_train_H3K4me3)
coef = param["coef"]
coef = np.array(coef, dtype = 'float64')
print(np.count_nonzero(coef))
np.set_printoptions(formatter={'float_kind':'{:f}'.format})
print(coef)
b = np.sort(coef)
print(b)
# Out:
# 30
# [0.083487 0.035568 0.006085 0.029689 0.104137 0.011417 0.004659 0.062741
#  0.003487 0.109399 0.039053 0.122498 0.041044 0.005618 0.006207 0.028472
#  0.002622 0.010195 0.082123 0.002566 0.000006 0.036303 0.018983 0.049258
#  0.030465 0.010066 0.014501 0.008607 0.024804 0.015939]
# [0.000006 0.002566 0.002622 0.003487 0.004659 0.005618 0.006085 0.006207
#  0.008607 0.010066 0.010195 0.011417 0.014501 0.015939 0.018983 0.024804
#  0.028472 0.029689 0.030465 0.035568 0.036303 0.039053 0.041044 0.049258
#  0.062741 0.082123 0.083487 0.104137 0.109399 0.122498]

# %%
features = coef>=0.028
X_train_H3K4me3 = X_train_H3K4me3[:,features]
print(X_train_H3K4me3.shape)
# Out:
# (18599, 14)

# %%
val_neg_sample = train_neg_sample + int(ma.ceil(neg_sam_H3K4me3.shape[0] *0.1))
val_pos_sample = train_pos_sample + int(ma.ceil(pos_sam_H3K4me3.shape[0] *0.1))
val_neg_H3K4me3 = neg_sam_H3K4me3[train_neg_sample:val_neg_sample,:]
val_pos_H3K4me3 = pos_sam_H3K4me3[train_pos_sample:val_pos_sample,:]
val_neg_pos_H3K4me3 = np.concatenate((val_neg_H3K4me3, val_pos_H3K4me3),axis = 0)
np.random.shuffle(val_neg_pos_H3K4me3)
X_val_H3K4me3 = val_neg_pos_H3K4me3[:,0:30]
Y_val_H3K4me3 = val_neg_pos_H3K4me3[:,30]
Y_val_H3K4me3 = np.array(Y_val_H3K4me3, dtype='int8')
frq = np.bincount(Y_val_H3K4me3)
print(frq)
print(X_val_H3K4me3.shape)
print(Y_val_H3K4me3.shape)   
print(X_val_H3K4me3.shape)
X_val_H3K4me3 = X_val_H3K4me3[:,features]
print(X_val_H3K4me3.shape)
# Out:
# [2410  247]
# (2657, 30)
# (2657,)
# (2657, 30)
# (2657, 14)

# %%
test_neg_H3K4me3 = neg_sam_H3K4me3[val_neg_sample:,:]
test_pos_H3K4me3 = pos_sam_H3K4me3 [val_pos_sample:,:]
test_neg_pos_H3K4me3 = np.concatenate((test_neg_H3K4me3, test_pos_H3K4me3),axis = 0)
np.random.shuffle(test_neg_pos_H3K4me3)
X_test_H3K4me3 = test_neg_pos_H3K4me3[:,0:30]
Y_test_H3K4me3 = test_neg_pos_H3K4me3[:,30]
Y_test_H3K4me3 = np.array(Y_test_H3K4me3, dtype='int8')
frq = np.bincount(Y_test_H3K4me3)
print(frq)
print(X_test_H3K4me3.shape)
print(Y_test_H3K4me3.shape) 
gbcmodel = param["model"]
y_pred = gbcmodel.predict(X_test_H3K4me3)
print('GBC model')
print(roc_auc_score(Y_test_H3K4me3, y_pred))
print(average_precision_score(Y_test_H3K4me3, y_pred))
X_test_H3K27me3 = X_test_H3K4me3[:, features]
print(frq)
print(X_test_H3K4me3.shape)
print(Y_test_H3K4me3.shape)
X_test_H3K4me3 = X_test_H3K4me3[:,features]
print(X_test_H3K4me3.shape)
# Out:
# [4819  494]
# (5313, 30)
# (5313,)
# GBC model
# 0.762668729464
# 0.46716573349
# [4819  494]
# (5313, 30)
# (5313,)
# (5313, 14)

# %%
 model = Sequential()
 #model.add(Bidirectional(LSTM(30, return_sequences=True),input_shape=(30,1)))
 #model.add(Dropout(0.5))
 #model.add(Flatten())
 #model.summary()
 #model.add(Dense(units=256, input_dim=30, activation="relu", kernel_initializer='glorot_uniform'))
 #model.add(Dropout(0.1))
 model.add(Dense(units=256, input_dim=14, activation="relu",kernel_initializer='glorot_uniform')) 
 model.add(Dropout(0.3))
 model.add(Dense(units=180,  activation="relu",kernel_initializer='glorot_uniform'))
 model.add(Dropout(0.3))
 #model.add(Dropout(0.1))
 model.add(Dense(units= 60, activation="relu",kernel_initializer='glorot_uniform')) 
 #model.add(Dropout(0.8))
 #model.add(Dense(units=10, activation="relu",kernel_initializer='glorot_uniform'))
 model.add(Dense(units=1,  activation="sigmoid"))  
 #adam = SGD(lr=0.0001, momentum=0.95, nesterov=True)
 #adam = Nadam(lr = 0.0001)
 model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_41 (Dense)             (None, 256)               3840
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_42 (Dense)             (None, 180)               46260
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 180)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 60)                10860
# _________________________________________________________________
# dense_44 (Dense)             (None, 1)                 61
# =================================================================
# Total params: 61,021
# Trainable params: 61,021
# Non-trainable params: 0
# _________________________________________________________________

# %%
 adam = Adam(lr = 0.0001)
 model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
 print('running at most 60 epochs')
 checkpointer = ModelCheckpoint(filepath="HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5",verbose=1, monitor='val_loss',save_best_only=True)
 earlystopper = EarlyStopping(monitor='val_loss', patience=10, verbose=1)
 model.fit(X_train_H3K4me3, Y_train_H3K4me3, batch_size=10, epochs=90, shuffle=True, validation_data=( X_val_H3K4me3, Y_val_H3K4me3), callbacks=[checkpointer,earlystopper])
 #model.fit(X_train_s, Y_train_s, batch_size=12, epochs=50, shuffle=True, validation_data=( X_val_s, Y_val_s), callbacks=[checkpointer,earlystopper])
 y_pred = model.predict(X_test_H3K4me3)
 
 np.savetxt('H3K4me3_true.csv', Y_test_H3K4me3, delimiter=",")
 np.savetxt('H3K4me3_pred.csv', y_pred, delimiter=",")
 #y_pred = model.predict(X_test_s)
 #tresults = model.evaluate(X_test_s, Y_test_s)
 tresults = model.evaluate(X_test_H3K4me3, Y_test_H3K4me3)
 print(tresults)
 model.summary()		
 #print(roc_auc_score(Y_test_s,y_pred))
 print(roc_auc_score(Y_test_H3K4me3, y_pred))
 print(average_precision_score(Y_test_H3K4me3, y_pred))
# Out:
# running at most 60 epochs
# Train on 18599 samples, validate on 2657 samples
# Epoch 1/90
# 18520/18599 [============================>.] - ETA: 0s - loss: 0.2669 - acc: 0.9157
# Epoch 00001: val_loss improved from inf to 0.19657, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 7s 395us/step - loss: 0.2669 - acc: 0.9158 - val_loss: 0.1966 - val_acc: 0.9364
# Epoch 2/90
# 18460/18599 [============================>.] - ETA: 0s - loss: 0.1963 - acc: 0.9316
# Epoch 00002: val_loss improved from 0.19657 to 0.17471, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 7s 359us/step - loss: 0.1969 - acc: 0.9313 - val_loss: 0.1747 - val_acc: 0.9420
# Epoch 3/90
# 18450/18599 [============================>.] - ETA: 0s - loss: 0.1819 - acc: 0.9353
# Epoch 00003: val_loss improved from 0.17471 to 0.16682, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 7s 369us/step - loss: 0.1818 - acc: 0.9352 - val_loss: 0.1668 - val_acc: 0.9451
# Epoch 4/90
# 18540/18599 [============================>.] - ETA: 0s - loss: 0.1743 - acc: 0.9369
# Epoch 00004: val_loss improved from 0.16682 to 0.16056, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 6s 300us/step - loss: 0.1741 - acc: 0.9370 - val_loss: 0.1606 - val_acc: 0.9447
# Epoch 5/90
# 18460/18599 [============================>.] - ETA: 0s - loss: 0.1655 - acc: 0.9395
# Epoch 00005: val_loss improved from 0.16056 to 0.16052, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 5s 290us/step - loss: 0.1658 - acc: 0.9394 - val_loss: 0.1605 - val_acc: 0.9435
# Epoch 6/90
# 18590/18599 [============================>.] - ETA: 0s - loss: 0.1578 - acc: 0.9412
# Epoch 00006: val_loss improved from 0.16052 to 0.15678, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 5s 290us/step - loss: 0.1578 - acc: 0.9412 - val_loss: 0.1568 - val_acc: 0.9458
# Epoch 7/90
# 18490/18599 [============================>.] - ETA: 0s - loss: 0.1572 - acc: 0.9413
# Epoch 00007: val_loss improved from 0.15678 to 0.15276, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 5s 289us/step - loss: 0.1568 - acc: 0.9414 - val_loss: 0.1528 - val_acc: 0.9484
# Epoch 8/90
# 18470/18599 [============================>.] - ETA: 0s - loss: 0.1549 - acc: 0.9445
# Epoch 00008: val_loss improved from 0.15276 to 0.14951, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 5s 293us/step - loss: 0.1550 - acc: 0.9446 - val_loss: 0.1495 - val_acc: 0.9469
# Epoch 9/90
# 18430/18599 [============================>.] - ETA: 0s - loss: 0.1509 - acc: 0.9441
# Epoch 00009: val_loss did not improve
# 18599/18599 [==============================] - 6s 332us/step - loss: 0.1514 - acc: 0.9441 - val_loss: 0.1536 - val_acc: 0.9447
# Epoch 10/90
# 18460/18599 [============================>.] - ETA: 0s - loss: 0.1499 - acc: 0.9432
# Epoch 00010: val_loss improved from 0.14951 to 0.14803, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 6s 298us/step - loss: 0.1500 - acc: 0.9431 - val_loss: 0.1480 - val_acc: 0.9511
# Epoch 11/90
# 18560/18599 [============================>.] - ETA: 0s - loss: 0.1501 - acc: 0.9452
# Epoch 00011: val_loss did not improve
# 18599/18599 [==============================] - 5s 295us/step - loss: 0.1500 - acc: 0.9453 - val_loss: 0.1532 - val_acc: 0.9484
# Epoch 12/90
# 18420/18599 [============================>.] - ETA: 0s - loss: 0.1455 - acc: 0.9461
# Epoch 00012: val_loss did not improve
# 18599/18599 [==============================] - 6s 297us/step - loss: 0.1457 - acc: 0.9461 - val_loss: 0.1524 - val_acc: 0.9428
# Epoch 13/90
# 18540/18599 [============================>.] - ETA: 0s - loss: 0.1459 - acc: 0.9451
# Epoch 00013: val_loss improved from 0.14803 to 0.14598, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 6s 313us/step - loss: 0.1457 - acc: 0.9452 - val_loss: 0.1460 - val_acc: 0.9507
# Epoch 14/90
# 18400/18599 [============================>.] - ETA: 0s - loss: 0.1441 - acc: 0.9466
# Epoch 00014: val_loss improved from 0.14598 to 0.14409, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 6s 315us/step - loss: 0.1439 - acc: 0.9467 - val_loss: 0.1441 - val_acc: 0.9481
# Epoch 15/90
# 18430/18599 [============================>.] - ETA: 0s - loss: 0.1419 - acc: 0.9473
# Epoch 00015: val_loss improved from 0.14409 to 0.14315, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 5s 284us/step - loss: 0.1424 - acc: 0.9473 - val_loss: 0.1431 - val_acc: 0.9526
# Epoch 16/90
# 18410/18599 [============================>.] - ETA: 0s - loss: 0.1391 - acc: 0.9487
# Epoch 00016: val_loss improved from 0.14315 to 0.14263, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 5s 281us/step - loss: 0.1394 - acc: 0.9487 - val_loss: 0.1426 - val_acc: 0.9499
# Epoch 17/90
# 18480/18599 [============================>.] - ETA: 0s - loss: 0.1423 - acc: 0.9461
# Epoch 00017: val_loss improved from 0.14263 to 0.14221, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 5s 283us/step - loss: 0.1417 - acc: 0.9464 - val_loss: 0.1422 - val_acc: 0.9496
# Epoch 18/90
# 18580/18599 [============================>.] - ETA: 0s - loss: 0.1413 - acc: 0.9463
# Epoch 00018: val_loss improved from 0.14221 to 0.14197, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 5s 284us/step - loss: 0.1412 - acc: 0.9463 - val_loss: 0.1420 - val_acc: 0.9526
# Epoch 19/90
# 18550/18599 [============================>.] - ETA: 0s - loss: 0.1377 - acc: 0.9477
# Epoch 00019: val_loss improved from 0.14197 to 0.14189, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 6s 307us/step - loss: 0.1376 - acc: 0.9477 - val_loss: 0.1419 - val_acc: 0.9496
# Epoch 20/90
# 18500/18599 [============================>.] - ETA: 0s - loss: 0.1376 - acc: 0.9483
# Epoch 00020: val_loss improved from 0.14189 to 0.14081, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 5s 283us/step - loss: 0.1377 - acc: 0.9482 - val_loss: 0.1408 - val_acc: 0.9511
# Epoch 21/90
# 18470/18599 [============================>.] - ETA: 0s - loss: 0.1386 - acc: 0.9498
# Epoch 00021: val_loss did not improve
# 18599/18599 [==============================] - 5s 283us/step - loss: 0.1384 - acc: 0.9499 - val_loss: 0.1474 - val_acc: 0.9484
# Epoch 22/90
# 18500/18599 [============================>.] - ETA: 0s - loss: 0.1350 - acc: 0.9486
# Epoch 00022: val_loss did not improve
# 18599/18599 [==============================] - 5s 287us/step - loss: 0.1348 - acc: 0.9488 - val_loss: 0.1426 - val_acc: 0.9514
# Epoch 23/90
# 18430/18599 [============================>.] - ETA: 0s - loss: 0.1341 - acc: 0.9493
# Epoch 00023: val_loss did not improve
# 18599/18599 [==============================] - 5s 280us/step - loss: 0.1338 - acc: 0.9495 - val_loss: 0.1409 - val_acc: 0.9507
# Epoch 24/90
# 18410/18599 [============================>.] - ETA: 0s - loss: 0.1339 - acc: 0.9500
# Epoch 00024: val_loss improved from 0.14081 to 0.13937, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 5s 284us/step - loss: 0.1349 - acc: 0.9497 - val_loss: 0.1394 - val_acc: 0.9522
# Epoch 25/90
# 18420/18599 [============================>.] - ETA: 0s - loss: 0.1323 - acc: 0.9490
# Epoch 00025: val_loss did not improve
# 18599/18599 [==============================] - 5s 290us/step - loss: 0.1323 - acc: 0.9489 - val_loss: 0.1434 - val_acc: 0.9514
# Epoch 26/90
# 18580/18599 [============================>.] - ETA: 0s - loss: 0.1322 - acc: 0.9492
# Epoch 00026: val_loss did not improve
# 18599/18599 [==============================] - 5s 281us/step - loss: 0.1322 - acc: 0.9491 - val_loss: 0.1400 - val_acc: 0.9477
# Epoch 27/90
# 18570/18599 [============================>.] - ETA: 0s - loss: 0.1319 - acc: 0.9513
# Epoch 00027: val_loss did not improve
# 18599/18599 [==============================] - 5s 281us/step - loss: 0.1321 - acc: 0.9513 - val_loss: 0.1452 - val_acc: 0.9481
# Epoch 28/90
# 18520/18599 [============================>.] - ETA: 0s - loss: 0.1293 - acc: 0.9522
# Epoch 00028: val_loss improved from 0.13937 to 0.13854, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 5s 289us/step - loss: 0.1301 - acc: 0.9520 - val_loss: 0.1385 - val_acc: 0.9499
# Epoch 29/90
# 18540/18599 [============================>.] - ETA: 0s - loss: 0.1296 - acc: 0.9515
# Epoch 00029: val_loss improved from 0.13854 to 0.13689, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 5s 283us/step - loss: 0.1296 - acc: 0.9515 - val_loss: 0.1369 - val_acc: 0.9518
# Epoch 30/90
# 18410/18599 [============================>.] - ETA: 0s - loss: 0.1312 - acc: 0.9515
# Epoch 00030: val_loss did not improve
# 18599/18599 [==============================] - 5s 280us/step - loss: 0.1311 - acc: 0.9517 - val_loss: 0.1372 - val_acc: 0.9503
# Epoch 31/90
# 18590/18599 [============================>.] - ETA: 0s - loss: 0.1300 - acc: 0.9517
# Epoch 00031: val_loss improved from 0.13689 to 0.13531, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 6s 322us/step - loss: 0.1299 - acc: 0.9517 - val_loss: 0.1353 - val_acc: 0.9499
# Epoch 32/90
# 18480/18599 [============================>.] - ETA: 0s - loss: 0.1309 - acc: 0.9498
# Epoch 00032: val_loss improved from 0.13531 to 0.13495, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 6s 296us/step - loss: 0.1307 - acc: 0.9499 - val_loss: 0.1349 - val_acc: 0.9492
# Epoch 33/90
# 18560/18599 [============================>.] - ETA: 0s - loss: 0.1294 - acc: 0.9519
# Epoch 00033: val_loss did not improve
# 18599/18599 [==============================] - 6s 305us/step - loss: 0.1293 - acc: 0.9519 - val_loss: 0.1387 - val_acc: 0.9469
# Epoch 34/90
# 18540/18599 [============================>.] - ETA: 0s - loss: 0.1296 - acc: 0.9509
# Epoch 00034: val_loss improved from 0.13495 to 0.13468, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 7s 351us/step - loss: 0.1295 - acc: 0.9510 - val_loss: 0.1347 - val_acc: 0.9530
# Epoch 35/90
# 18460/18599 [============================>.] - ETA: 0s - loss: 0.1270 - acc: 0.9524
# Epoch 00035: val_loss did not improve
# 18599/18599 [==============================] - 5s 285us/step - loss: 0.1273 - acc: 0.9522 - val_loss: 0.1355 - val_acc: 0.9526
# Epoch 36/90
# 18530/18599 [============================>.] - ETA: 0s - loss: 0.1276 - acc: 0.9515
# Epoch 00036: val_loss did not improve
# 18599/18599 [==============================] - 6s 329us/step - loss: 0.1275 - acc: 0.9516 - val_loss: 0.1358 - val_acc: 0.9492
# Epoch 37/90
# 18590/18599 [============================>.] - ETA: 0s - loss: 0.1281 - acc: 0.9526
# Epoch 00037: val_loss improved from 0.13468 to 0.13403, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 5s 281us/step - loss: 0.1280 - acc: 0.9526 - val_loss: 0.1340 - val_acc: 0.9492
# Epoch 38/90
# 18530/18599 [============================>.] - ETA: 0s - loss: 0.1251 - acc: 0.9532
# Epoch 00038: val_loss did not improve
# 18599/18599 [==============================] - 5s 282us/step - loss: 0.1247 - acc: 0.9533 - val_loss: 0.1359 - val_acc: 0.9473
# Epoch 39/90
# 18510/18599 [============================>.] - ETA: 0s - loss: 0.1254 - acc: 0.9531
# Epoch 00039: val_loss did not improve
# 18599/18599 [==============================] - 5s 282us/step - loss: 0.1252 - acc: 0.9532 - val_loss: 0.1369 - val_acc: 0.9458
# Epoch 40/90
# 18420/18599 [============================>.] - ETA: 0s - loss: 0.1249 - acc: 0.9542
# Epoch 00040: val_loss did not improve
# 18599/18599 [==============================] - 5s 280us/step - loss: 0.1252 - acc: 0.9540 - val_loss: 0.1357 - val_acc: 0.9481
# Epoch 41/90
# 18480/18599 [============================>.] - ETA: 0s - loss: 0.1264 - acc: 0.9517
# Epoch 00041: val_loss did not improve
# 18599/18599 [==============================] - 5s 251us/step - loss: 0.1262 - acc: 0.9518 - val_loss: 0.1354 - val_acc: 0.9492
# Epoch 42/90
# 18590/18599 [============================>.] - ETA: 0s - loss: 0.1252 - acc: 0.9526
# Epoch 00042: val_loss improved from 0.13403 to 0.13351, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 5s 282us/step - loss: 0.1253 - acc: 0.9526 - val_loss: 0.1335 - val_acc: 0.9499
# Epoch 43/90
# 18550/18599 [============================>.] - ETA: 0s - loss: 0.1241 - acc: 0.9541
# Epoch 00043: val_loss did not improve
# 18599/18599 [==============================] - 5s 282us/step - loss: 0.1241 - acc: 0.9540 - val_loss: 0.1370 - val_acc: 0.9503
# Epoch 44/90
# 18570/18599 [============================>.] - ETA: 0s - loss: 0.1247 - acc: 0.9540
# Epoch 00044: val_loss did not improve
# 18599/18599 [==============================] - 6s 305us/step - loss: 0.1247 - acc: 0.9540 - val_loss: 0.1345 - val_acc: 0.9514
# Epoch 45/90
# 18560/18599 [============================>.] - ETA: 0s - loss: 0.1252 - acc: 0.9539
# Epoch 00045: val_loss did not improve
# 18599/18599 [==============================] - 5s 283us/step - loss: 0.1252 - acc: 0.9539 - val_loss: 0.1352 - val_acc: 0.9503
# Epoch 46/90
# 18500/18599 [============================>.] - ETA: 0s - loss: 0.1224 - acc: 0.9531
# Epoch 00046: val_loss did not improve
# 18599/18599 [==============================] - 5s 282us/step - loss: 0.1233 - acc: 0.9527 - val_loss: 0.1400 - val_acc: 0.9503
# Epoch 47/90
# 18550/18599 [============================>.] - ETA: 0s - loss: 0.1229 - acc: 0.9537
# Epoch 00047: val_loss did not improve
# 18599/18599 [==============================] - 5s 288us/step - loss: 0.1228 - acc: 0.9538 - val_loss: 0.1350 - val_acc: 0.9492
# Epoch 48/90
# 18400/18599 [============================>.] - ETA: 0s - loss: 0.1211 - acc: 0.9548
# Epoch 00048: val_loss did not improve
# 18599/18599 [==============================] - 5s 284us/step - loss: 0.1211 - acc: 0.9549 - val_loss: 0.1339 - val_acc: 0.9503
# Epoch 49/90
# 18590/18599 [============================>.] - ETA: 0s - loss: 0.1216 - acc: 0.9537
# Epoch 00049: val_loss did not improve
# 18599/18599 [==============================] - 5s 281us/step - loss: 0.1215 - acc: 0.9537 - val_loss: 0.1359 - val_acc: 0.9503
# Epoch 50/90
# 18410/18599 [============================>.] - ETA: 0s - loss: 0.1228 - acc: 0.9538
# Epoch 00050: val_loss did not improve
# 18599/18599 [==============================] - 5s 280us/step - loss: 0.1230 - acc: 0.9537 - val_loss: 0.1388 - val_acc: 0.9511
# Epoch 51/90
# 18590/18599 [============================>.] - ETA: 0s - loss: 0.1216 - acc: 0.9543
# Epoch 00051: val_loss improved from 0.13351 to 0.13343, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 5s 284us/step - loss: 0.1216 - acc: 0.9544 - val_loss: 0.1334 - val_acc: 0.9499
# Epoch 52/90
# 18470/18599 [============================>.] - ETA: 0s - loss: 0.1210 - acc: 0.9549
# Epoch 00052: val_loss did not improve
# 18599/18599 [==============================] - 5s 284us/step - loss: 0.1208 - acc: 0.9549 - val_loss: 0.1343 - val_acc: 0.9477
# Epoch 53/90
# 18550/18599 [============================>.] - ETA: 0s - loss: 0.1212 - acc: 0.9540
# Epoch 00053: val_loss did not improve
# 18599/18599 [==============================] - 5s 279us/step - loss: 0.1212 - acc: 0.9540 - val_loss: 0.1377 - val_acc: 0.9496
# Epoch 54/90
# 18450/18599 [============================>.] - ETA: 0s - loss: 0.1209 - acc: 0.9548
# Epoch 00054: val_loss did not improve
# 18599/18599 [==============================] - 5s 281us/step - loss: 0.1214 - acc: 0.9546 - val_loss: 0.1369 - val_acc: 0.9507
# Epoch 55/90
# 18450/18599 [============================>.] - ETA: 0s - loss: 0.1207 - acc: 0.9553
# Epoch 00055: val_loss did not improve
# 18599/18599 [==============================] - 5s 282us/step - loss: 0.1204 - acc: 0.9554 - val_loss: 0.1348 - val_acc: 0.9488
# Epoch 56/90
# 18490/18599 [============================>.] - ETA: 0s - loss: 0.1187 - acc: 0.9550
# Epoch 00056: val_loss improved from 0.13343 to 0.13294, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 6s 298us/step - loss: 0.1190 - acc: 0.9549 - val_loss: 0.1329 - val_acc: 0.9522
# Epoch 57/90
# 18490/18599 [============================>.] - ETA: 0s - loss: 0.1212 - acc: 0.9557
# Epoch 00057: val_loss improved from 0.13294 to 0.13225, saving model to HistoneMark_H3K4me3_TF_ncl_GM12878.hdf5
# 18599/18599 [==============================] - 5s 294us/step - loss: 0.1214 - acc: 0.9555 - val_loss: 0.1322 - val_acc: 0.9507
# Epoch 58/90
# 18470/18599 [============================>.] - ETA: 0s - loss: 0.1206 - acc: 0.9556
# Epoch 00058: val_loss did not improve
# 18599/18599 [==============================] - 6s 318us/step - loss: 0.1204 - acc: 0.9556 - val_loss: 0.1348 - val_acc: 0.9503
# Epoch 59/90
# 18560/18599 [============================>.] - ETA: 0s - loss: 0.1182 - acc: 0.9551
# Epoch 00059: val_loss did not improve
# 18599/18599 [==============================] - 5s 288us/step - loss: 0.1183 - acc: 0.9550 - val_loss: 0.1323 - val_acc: 0.9522
# Epoch 60/90
# 18540/18599 [============================>.] - ETA: 0s - loss: 0.1190 - acc: 0.9546
# Epoch 00060: val_loss did not improve
# 18599/18599 [==============================] - 6s 329us/step - loss: 0.1190 - acc: 0.9546 - val_loss: 0.1344 - val_acc: 0.9507
# Epoch 61/90
# 18530/18599 [============================>.] - ETA: 0s - loss: 0.1188 - acc: 0.9555
# Epoch 00061: val_loss did not improve
# 18599/18599 [==============================] - 5s 293us/step - loss: 0.1187 - acc: 0.9556 - val_loss: 0.1344 - val_acc: 0.9507
# Epoch 62/90
# 18500/18599 [============================>.] - ETA: 0s - loss: 0.1175 - acc: 0.9550
# Epoch 00062: val_loss did not improve
# 18599/18599 [==============================] - 5s 284us/step - loss: 0.1176 - acc: 0.9550 - val_loss: 0.1398 - val_acc: 0.9522
# Epoch 63/90
# 18430/18599 [============================>.] - ETA: 0s - loss: 0.1180 - acc: 0.9554
# Epoch 00063: val_loss did not improve
# 18599/18599 [==============================] - 5s 283us/step - loss: 0.1181 - acc: 0.9554 - val_loss: 0.1325 - val_acc: 0.9522
# Epoch 64/90
# 18590/18599 [============================>.] - ETA: 0s - loss: 0.1167 - acc: 0.9558
# Epoch 00064: val_loss did not improve
# 18599/18599 [==============================] - 5s 290us/step - loss: 0.1170 - acc: 0.9558 - val_loss: 0.1347 - val_acc: 0.9511
# Epoch 65/90
# 18490/18599 [============================>.] - ETA: 0s - loss: 0.1167 - acc: 0.9555
# Epoch 00065: val_loss did not improve
# 18599/18599 [==============================] - 6s 328us/step - loss: 0.1168 - acc: 0.9555 - val_loss: 0.1341 - val_acc: 0.9526
# Epoch 66/90
# 18430/18599 [============================>.] - ETA: 0s - loss: 0.1164 - acc: 0.9557
# Epoch 00066: val_loss did not improve
# 18599/18599 [==============================] - 5s 285us/step - loss: 0.1165 - acc: 0.9558 - val_loss: 0.1348 - val_acc: 0.9496
# Epoch 67/90
# 18440/18599 [============================>.] - ETA: 0s - loss: 0.1169 - acc: 0.9556
# Epoch 00067: val_loss did not improve
# 18599/18599 [==============================] - 5s 285us/step - loss: 0.1167 - acc: 0.9557 - val_loss: 0.1419 - val_acc: 0.9477
# Epoch 00067: early stopping
# 5313/5313 [==============================] - 0s 27us/step
# [0.15635127215077388, 0.94071146245059289]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_41 (Dense)             (None, 256)               3840
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_42 (Dense)             (None, 180)               46260
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 180)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 60)                10860
# _________________________________________________________________
# dense_44 (Dense)             (None, 1)                 61
# =================================================================
# Total params: 61,021
# Trainable params: 61,021
# Non-trainable params: 0
# _________________________________________________________________
# 0.943987320769
# 0.728733713977

# %%
fpr, tpr, threshold = roc_curve(Y_test_H3K4me3, y_pred)
roc_auc = auc(fpr, tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
precision, recall, thresholds = precision_recall_curve(Y_test_H3K4me3, y_pred)
pr_auc = average_precision_score(Y_test_H3K4me3, y_pred)
plt.title('Precision Recall Curve')
plt.plot(recall, precision, 'b', label = 'AUC = %0.2f' % pr_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
y_pred = (y_pred>0.5)
cm = confusion_matrix(Y_test_H3K4me3, y_pred)
print(cm)
